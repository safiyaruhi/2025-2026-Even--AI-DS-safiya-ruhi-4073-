# %% [markdown]
# <a href="https://colab.research.google.com/github/safiyaruhi/2025-2026-Even--AI-DS-safiya-ruhi-4073-/blob/main/week1-(03-02-26).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list_a=[0,1,2,3,4,5]
print(list_a)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
tuple_b=(9,8,7,6,5)
print(tuple_b)
# Out:
# (9, 8, 7, 6, 5)

# %%
set_c={'apple','banana'}
print(set_c)
# Out:
# {'apple', 'banana'}

# %%
dictionary_d={'a':23,"b":55}
print(dictionary_d)
# Out:
# {'a': 23, 'b': 55}

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/GeostatsGuy/GeoDataSets/master/12_sample_data.csv"
df = pd.read_csv(url)
print(df.head())
df.to_csv(r"D:\sample_data.csv", index=False)
print("Dataset saved successfully to local drive")
# Out:
#    Unnamed: 0           X            Y  Facies  Porosity        Perm  \
# 0           0  502.929859  9008.972357       1  0.220761  140.021266
# 1           1  508.696361  8505.744515       1  0.237154   39.837129
# 2           2  503.892888  8003.429847       1  0.234352   84.992437
# 3           3  508.230145  7509.751406       1  0.244553   90.632307
# 4           4  500.611637  7000.684230       1  0.231787  811.547979
#
#             AI
# 0  3413.063944
# 1  3074.562617
# 2  2292.783358
# 3  2494.848885
# 4  2522.063995
# Dataset saved successfully to local drive
